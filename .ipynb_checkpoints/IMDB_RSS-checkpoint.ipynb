# %%
import json
import numpy as np
import matplotlib as plt
# %matplotlib inline
import pandas as pd
import feedparser as fp
import requests
import datetime
from operator import itemgetter
from Replace import replace, unwanted_titles

entries = fp.parse('https://thepiratebay.org/rss/top100/201')['entries']

# Month Dictionary for replacing %b month format with numeric format
month_dict = {"Jan": 1, "Feb": 2, "Mar": 3, "Apr": 4, "May": 5, "Jun": 6,
              "Jul": 7, "Aug": 8, "Sep": 9, "Oct": 10,"Nov": 11, "Dec": 12}

# API key for omdbapi.com. This is a distinct key per user. Non-paterion users limits to 1000 post requests per day.
api_key = "1b1c7b21"

# Recording types that are not about Standard Definition
udrts = ["HDCAM", "HD CAM","TS","HD-TS","HDTS","HD-TC","HDTC"]

# %%
def trim_magnet(magnet_link):
    """Trims the extra information from the magnet link"""
    show_name = magnet_link.replace(".", " ").strip()
    show_name = show_name.replace("+", " ").strip()
    for value in replace:
        show_name = show_name.replace(value, "")
        
    for y in range(1900, 2020):
        if str(y) in show_name:
            show_name = show_name.replace(str(y), "")
            
    return show_name

# %%
def format_dateYYYYMMDD(date):
    """formats date as yyyy-mm-dd"""
    date_list = date.split()
    year = int(date_list[2])
    month = month_dict.get(date_list[1])
    day = int(date_list[0])
    new_date = "{}".format(datetime.date(year, month, day))
    return new_date

# %%
def get_movie_info():
    """Gets movie data from omdbapi.com"""
    resp_list = []
    for entry in entries:
        magnet_link = entry['title']
        if all(udrt not in magnet_link for udrt in udrts):
            title = trim_magnet(magnet_link)
            print(title)
            try:
                url = "http://www.omdbapi.com/?t=" + title + "&tomatoes=true&apikey=" + api_key
                resp = requests.get(url)
                jsonvalues = resp.json()
                if "Title" in jsonvalues:
                    if "N/A" not in jsonvalues["Released"]:
                        new_date = format_dateYYYYMMDD(jsonvalues["Released"])
                        jsonvalues["Released"] = new_date
                    resp_list.append(jsonvalues)
            except KeyError as err:
                print(err)
    return resp_list
resp_list = get_movie_info()
# Out:
# Jurassic World Fallen
# Skyscraper
# Escape Plan 2
# Den of Thieves
# Blade Runner 2049
# Satyameva Jayate
# Gold
# Three Billboards Outside Ebbing,Missouri
# Adrift
# Ready Player One
# Patient Zero
# The Greatest Showman
# Avengers Infinity War
# Skyscraper
# A Quiet Place
# The Shape of Water
# Time Trap
# Logan
# The Little Mermaid
# Call Me By Your Name
# Avengers Infinity War
# Lady Bird
# Crazy Rich Asians
# Tomb Raider
# To All the Boys Ive Loved Before
# Red Sparrow
# The Post
# Rampage
# The Equalizer
# Pirates of the Caribbean Dead Men Tell No Tales
# La La Land
# The Death of Stalin
# The Disaster Artist
# I,Tonya
# Gotti
# Phantom Thread
# Boar
# The Killing of a Sacred Deer
# The Kissing Booth
# Breaking And Exiting
# Wonder
# Traffik
# American Animals
# All the Money in the World
# Breaking In
# Traffik
# IT
# Get Out
# The Ninth Passenger
# The Revenant
# Upgrade
# A Prayer Before Dawn
# Game Night
# Mollys Game
# Forever My Girl
# SpiderMan Homeing
# Murder on the Orient Express
# Deadpool 2
# Darkest Hour
# Sicario
# Dr Strange
# I Kill Giants
# Death Wish
# John Wick Chapter 2

# %%
# Writes output to file to limit unnecessary post requests
with open("report.json", "w") as out_file:
    json.dump(resp_list, out_file)
    
with open('report.json') as f:
    data = json.load(f)

# %%
# Sorts json data by released date
sorted_data = sorted(data, key=itemgetter("Released"), reverse=True)

# %%
df = pd.read_json(json.dumps(sorted_data))

df2 = df[['Title', 'imdbRating', 'Metascore']].drop_duplicates()
df2 = df2[~df2['Title'].isin(unwanted_titles)]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df2)
# Out:
#                                         Title imdbRating Metascore
# 0                            Satyameva Jayate        5.3       N/A
# 1                                   Time Trap        6.8       N/A
# 2                         The Ninth Passenger        8.8       N/A
# 3                                        Boar        7.8       N/A
# 5                           Crazy Rich Asians        N/A       N/A
# 10                                     Adrift        6.7        56
# 16                                    Traffik        6.3        37
# 23                        The Death of Stalin        7.2        88
# 25                                 Death Wish        6.4        31
# 27                             Den of Thieves        7.0        49
# 29                                   I, Tonya        7.5        77
# 30                             Phantom Thread        7.6        90
# 31                            Forever My Girl        6.6        36
# 32                                   The Post        7.2        83
# 33                 All the Money in the World        6.9        72
# 35                               Darkest Hour        7.4        75
# 36                       The Greatest Showman        7.7        48
# 38  Three Billboards Outside Ebbing, Missouri        8.2        88
# 40                                     Wonder        8.0        66
# 41               Murder on the Orient Express        6.5        52
# 42               The Killing of a Sacred Deer        7.1        73
# 44                                         It        7.4        69
# 48                       John Wick: Chapter 2        7.5        75
# 49                                       Gold        6.7        49
# 52                                    Sicario        7.6        82
# 53                                 Dr Strange        N/A       N/A
# 54                              The Equalizer        7.2        57
# 55                               Patient Zero        6.8       N/A
# 56                                Breaking In        7.2       N/A
# 57                                      Gotti        7.3       N/A
# 58                         The Little Mermaid        7.6        88

# %%
df2 = df2[df2['imdbRating'] != 'N/A']
df2 = df2[df2['Metascore'] != 'N/A']
df2['imdbRating'] = (df2['imdbRating'].astype(float) * 10).astype(int)
df2['Metascore'] = df2['Metascore'].astype(int)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df2)
# Out:
#                                         Title  imdbRating  Metascore
# 10                                     Adrift          67         56
# 16                                    Traffik          63         37
# 23                        The Death of Stalin          72         88
# 25                                 Death Wish          64         31
# 27                             Den of Thieves          70         49
# 29                                   I, Tonya          75         77
# 30                             Phantom Thread          76         90
# 31                            Forever My Girl          66         36
# 32                                   The Post          72         83
# 33                 All the Money in the World          69         72
# 35                               Darkest Hour          74         75
# 36                       The Greatest Showman          77         48
# 38  Three Billboards Outside Ebbing, Missouri          82         88
# 40                                     Wonder          80         66
# 41               Murder on the Orient Express          65         52
# 42               The Killing of a Sacred Deer          71         73
# 44                                         It          74         69
# 48                       John Wick: Chapter 2          75         75
# 49                                       Gold          67         49
# 52                                    Sicario          76         82
# 54                              The Equalizer          72         57
# 58                         The Little Mermaid          76         88

# %%
display(df2.plot(title='Movie Ranking',x='Title',
                 figsize=(40,10), kind='bar',fontsize=20))
